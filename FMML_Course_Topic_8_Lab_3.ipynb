# %% [markdown]
# <a href="https://colab.research.google.com/github/amar4143/FMML-ASSIGNMENT--1/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-04 15:18:54--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   125MB/s    in 0.6s
#
# 2023-05-04 15:18:56 (125 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 32983  1512.04455v1  Partially observed control problems are a chal...    cs
# 21016  1706.06366v2  The highly influential framework of conceptual...    cs
# 6640   1704.06256v2  We consider the robust phase retrieval problem...  stat
# 12838  1709.05865v1  Depression is a major mental health disorder t...    cs
# 6847   1706.07642v2  Active learning aims to train a classifier as ...  stat
# ...             ...                                                ...   ...
# 16101  1609.07451v1  The task of AMR-to-text generation is to gener...    cs
# 10306   1201.0794v2  We present some nonparametric methods for grap...  stat
# 22809  1707.04191v3  We propose a novel, theoretically-grounded, ac...  stat
# 11881  1703.03208v1  The goal of compressed sensing is to estimate ...  stat
# 912    1708.02975v2  In this paper, we use variational recurrent ne...    cs
#
#                                                    title  year  \
# 32983  Memory-based control with recurrent neural net...  2015
# 21016      A Thorough Formalization of Conceptual Spaces  2017
# 6640   Robust Wirtinger Flow for Phase Retrieval with...  2017
# 12838  Depression Scale Recognition from Audio, Visua...  2017
# 6847   A Variance Maximization Criterion for Active L...  2017
# ...                                                  ...   ...
# 16101  AMR-to-text generation as a Traveling Salesman...  2016
# 10306              Sparse Nonparametric Graphical Models  2012
# 22809  Distributionally Ambiguous Optimization Techni...  2017
# 11881         Compressed Sensing using Generative Models  2017
# 912               Anomaly Detection on Graph Time Series  2017
#
#                                                 keywords
# 32983  [partially, challenging, reinforcement, algori...
# 21016  [influential, framework, conceptual, geometric...
# 6640   [retrieval, recovering, magnitude, measurement...
# 12838  [depression, affecting, worldwide, depression,...
# 6847   [classifier, virtually, criterion, usefulness,...
# ...                                                  ...
# 16101  [generation, grammatical, partitioning, fragme...
# 10306  [nonparametric, graphical, essentially, nonpar...
# 22809  [theoretically, acquisition, optimization, dis...
# 11881  [compressed, underdetermined, measurements, kn...
# 912    [variational, recurrent, investigate, detectio...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 32983    [partially, challenging, reinforcement, algori...
# 21016    [influential, framework, conceptual, geometric...
# 6640     [retrieval, recovering, magnitude, measurement...
# 12838    [depression, affecting, worldwide, depression,...
# 6847     [classifier, virtually, criterion, usefulness,...
#                                ...
# 12029    [stochastic, posterior, iteration, computation...
# 10888    [childhood, adolescence, identifying, predicti...
# 11063    [describes, recognition, electrochemical, impe...
# 30605    [attributesvms, attribute, representation, inf...
# 34060    [extraction, frontiers, biomedical, processing...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8753 words.
# Out of those 4568 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="382fb483-0b24-498e-a0b8-bf5fa37c3269" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("382fb483-0b24-498e-a0b8-bf5fa37c3269")) {                    Plotly.newPlot(                        "382fb483-0b24-498e-a0b8-bf5fa37c3269",                        [{"x":["demonstrate","exploration","effective","exhibiting","integration","continuous","dimensional","challenging","including","recurrent","solutions","similarly","deterministic","identification","algorithms","strategies","observations","information","simplified","stochastic","backpropagation","partially","parameters","preserving","assortment","requirements","reinforcement","reasoning","parametric","represented","geometric","requirement","represent","framework","efficient","conceptual","operations","formalization","correlations","different","convexity","computationally","representing","projection","knowledge","influential","definition","instances","processes","recovering","statistical","nonconvex","algorithm","corruption","synthetic","contaminated","retrieval","magnitude","precision","corroborate","complexity","measurements","guaranteed","arbitrary","experiments","depression","psychological","challenge","worldwide","multimodal","independent","clustering","extraction","describes","automatically","descriptors","frustration","affecting","activities","extracted","recognition","emotional","classification","interview","validation","processing","maximizing","informativeness","unlabeled","variables","maximization","performance","respectively","benchmark","maintains","usefulness","variances","combination","labelling","retraining","perturbations","informative","technique","potential","classifier","classifiers","representative","evaluating","regression","virtually","criterion","dimensions","mainstream","differences","iterations","programming","interestingly","projections","recovered","sufficient","significant","understanding","idealized","procedure","consecutive","anomalies","applications","optimization","iteration","generated","baselines","detecting","intuition","compressed","comparisons","regardless","measurement","significantly","surveillance","typically","distribution","coordinates","orthogonal","localisation","supervised","generalises","differentiable","artifacts","detection","outperforming","manipulate","interpretable","therefore","compatibility","indicates","description","ontological","approaches","execution","interaction","important","databases","investigate","exchanged","verifying","possibility","published","conflicts","protocols","developed","interacting","inconsistent","relational","sequences","traditionally","incorporate","independently","ontologies","verification","semantically","commensurate","qualitative","tradition","determine","compatible","preference","introduce","transitivity","relaxation","uncertainty","investigates","numerical","consequences","requiring","representation","assumption","relations","particular","similarity","compression"],"y":[554,51,215,10,50,129,177,249,261,144,135,16,49,103,642,102,91,690,17,126,20,54,226,40,2,63,121,134,39,100,77,33,108,533,398,23,73,9,34,756,7,93,79,48,369,7,61,92,96,17,139,10,833,2,135,5,107,51,68,3,240,55,30,81,627,2,14,145,8,41,144,135,157,88,157,38,1,12,51,110,391,9,539,4,52,284,33,7,56,118,34,843,88,200,19,26,10,139,13,6,17,34,231,143,150,124,34,52,120,5,56,38,2,42,36,116,15,24,12,73,231,175,2,123,12,9,429,331,40,166,46,84,23,18,30,17,38,258,38,111,235,13,16,6,195,2,26,28,359,22,11,30,136,5,31,61,7,397,31,78,345,59,149,4,8,38,40,16,14,182,15,8,30,99,20,65,27,26,43,30,2,55,1,73,9,24,331,5,22,80,31,75,15,42,347,62,89,279,151,49],"type":"bar"},{"x":["demonstrate","exploration","effective","exhibiting","integration","continuous","dimensional"," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4568,), (4568, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.78

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.582089552238806);'>Contextual</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Hypergraph</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Modelling</span> <span style=''>for</span> <span style=''>Salient</span> <span style=''>Object</span> <span style='background-color:rgba(0, 255, 0, 0.4989561586638831);'>Detection</span> <br/><br/><span style=''>Salient</span> <span style=''>object</span> <span style='background-color:rgba(0, 255, 0, 0.4989561586638831);'>detection</span> <span style=''>aims</span> <span style=''>to</span> <span style=''>locate</span> <span style=''>objects</span> <span style=''>that</span> <span style=''>capture</span> <span style=''>human</span> <span style='background-color:rgba(0, 255, 0, 0.38271604938271614);'>attention</span> <span style=''>within</span> <span style=''>images</span> <span style=''>Previous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>often</span> <span style=''>pose</span> <span style=''>this</span> <span style=''>as</span> <span style=''>a</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>image</span> <span style=''>contrast</span> <span style=''>analysis</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>model</span> <span style=''>an</span> <span style=''>image</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hypergraph</span> <span style=''>that</span> <span style=''>utilizes</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>hyperedges</span> <span style=''>to</span> <span style=''>capture</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.582089552238806);'>contextual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>image</span> <span style=''>pixels</span> <span style=''>or</span> <span style=''>regions</span> <span style=''>As</span> <span style=''>a</span> <span style=''>result</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>salient</span> <span style=''>object</span> <span style='background-color:rgba(0, 255, 0, 0.4989561586638831);'>detection</span> <span style=''>becomes</span> <span style=''>one</span> <span style=''>of</span> <span style=''>finding</span> <span style=''>salient</span> <span style=''>vertices</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>hyperedges</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hypergraph</span> <span style=''>The</span> <span style=''>main</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>advantage</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hypergraph</span> <span style=''>modeling</span> <span style=''>is</span> <span style=''>that</span> <span style=''>it</span> <span style=''>takes</span> <span style=''>into</span> <span style=''>account</span> <span style=''>each</span> <span style=''>pixels</span> <span style=''>(or</span> <span style=''>regions)</span> <span style=''>affinity</span> <span style=''>with</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>neighborhood</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>separation</span> <span style=''>from</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.654320987654321);'>background</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Furthermore</span> <span style=''>we</span> <span style=''>propose</span> <s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Equivalence</span> <span style=''>of</span> <span style=''>distance</span> <span style=''>based</span> <span style=''>and</span> <span style=''>RKHS</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistics</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypothesis</span> <span style=''>testing</span> <br/><br/><span style=''>We</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>unifying</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>linking</span> <span style=''>two</span> <span style=''>classes</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistics</span> <span style=''>used</span> <span style=''>in</span> <span style=''>two</span> <span style=''>sample</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independence</span> <span style=''>testing</span> <span style=''>on</span> <span style=''>the</span> <span style=''>one</span> <span style=''>hand</span> <span style=''>the</span> <span style=''>energy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distances</span> <span style=''>and</span> <span style=''>distance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariances</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistics</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>literature</span> <span style=''>on</span> <span style=''>the</span> <span style=''>other</span> <span style=''>maximum</span> <span style=''>mean</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discrepancies</span> <span style=''>(MMD)</span> <span style=''>that</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distances</span> <span style=''>between</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embeddings</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reproducing</span> <span style=''>kernel</span> <span style=''>Hilbert</span> <span style=''>spaces</span> <span style=''>(RKHS)</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>established</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>In</span> <span style=''>the</span> <span style=''>case</span> <span style=''>where</span> <span style=''>the</span> <span style=''>energy</span> <span style=''>distance</span> <span style=''>is</span> <span style=''>computed</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>semimetric</span> <span style=''>of</span> <span style=''>negative</span> <span style=''>type</span> <span style=''>a</span> <span style=''>positive</span> <span style=''>definite</span> <span style=''>kernel</span> <span style=''>termed</span> <span style=''>distance</span> <span style=''>kernel</span> <span style=''>may</span> <span style=''>be</span> <span style=''>defined</span> <span style=''>such</span> <span style=''>that</span> <span style=''>the</span> <span style=''>MMD</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corresponds</span> <span style=''>exactly</span> <span style=''>to</span> <span style=''>the</span> <span style=''>energy</span> <span style=''>distance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Conversely</span> <span style=''>for</span> <span style=''>any</span> <span style=''>positive</span> <span style=''>definite</span> <span style=''>kernel</span> <span style=''>we</span> <span style=''>can</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpret</span> <span style=''>the</span> <span style=''>MMD</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Probabilistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithm</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>Calculating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Structure</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Borrowing</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3434343434343434);'>Simulated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Annealing</span> <br/><br/><span style=''>We</span> <span style=''>have</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>developed</span> <span style=''>a</span> <span style=''>general</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.34482758620689646);'>determining</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>coordinates</span> <span style=''>of</span> <span style=''>points</span> <span style=''>in</span> <span style=''>a</span> <span style=''>three</span> <span style='background-color:rgba(255, 0, 0, 0.3320754716981133);'>dimensional</span> <span style=''>space</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>takes</span> <span style=''>as</span> <span style=''>input</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>coordinates</span> <span style=''>of</span> <span style=''>the</span> <span style=''>points</span> <span style=''>and</span> <span style=''>an</span> <span style=''>a</span> <span style=''>priori</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>for</span> <span style=''>each</span> <span style=''>point</span> <span style=''>location</span> <span style=''>The</span> <span style=''>output</span> <span style=''>is</span> <span style=''>a</span> <span style=''>maximum</span> <span style='background-color:rgba(255, 0, 0, 0.5019455252918288);'>likelihood</span> <span style=''>estimate</span> <span style=''>of</span> <span style=''>the</span> <span style=''>location</span> <span style=''>of</span> <span style=''>each</span> <span style=''>point</span> <span style=''>We</span> <span style=''>use</span> <span style=''>the</span> <span style=''>extended</span> <span style=''>iterated</span> <span style=''>Kalman</span> <span style=''>filter</span> <span style=''>and</span> <span style=''>add</span> <span style=''>a</span> <span style=''>search</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>heuristic</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimizing</span> <span style=''>its</span> <span style=''>solution</span> <span style=''>under</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>nonlinear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>This</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>heuristic</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>same</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principle</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3434343434343434);'>simulated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>annealing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>heuristic</span> <span style=''>for</span> <span style=''>other</span> <span style='background-color:rgba(255, 0 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Context</span> <span style=''>models</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sequences</span> <span style=''>of</span> <span style=''>covers</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>class</span> <span style=''>of</span> <span style=''>models</span> <span style=''>that</span> <span style=''>via</span> <span style=''>a</span> <span style=''>simple</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>construction</span> <span style=''>enables</span> <span style=''>exact</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incremental</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>polynomial</span> <span style=''>time</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style=''>measures</span> <span style=''>The</span> <span style=''>approach</span> <span style=''>relies</span> <span style=''>upon</span> <span style=''>creating</span> <span style=''>a</span> <span style=''>sequence</span> <span style=''>of</span> <span style=''>covers</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditioning</span> <span style=''>variable</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>maintaining</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>model</span> <span style=''>for</span> <span style=''>each</span> <span style=''>set</span> <span style=''>within</span> <span style=''>a</span> <span style=''>cover</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>remains</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>tractable</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>specifying</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>model</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>a</span> <span style=''>random</span> <span style=''>walk</span> <span style=''>within</span> <span style=''>the</span> <span style=''>sequence</span> <span style=''>of</span> <span style=''>covers</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>the</span> <span style=''>approach</span> <span style=''>on</span> <span style=''>problems</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style=''>density</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>which</span> <span style=''>to</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>knowledge</span> <span style=''>is</span> <span style=''>the</span> <span style=''>first</span> <span style=''>closed</span> <span style=''>form</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametric</span> <span style=''>Bayesian</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>this</span> <span style=''>problem</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.12361952262201639)
# 	information (0.2458140363377271)
# 	segmentation (0.07053794086213039)
# 	architecture (0.08870680441752761)
# 	experimental (0.1396508728179551)
# 	knowledge (0.13145707160669753)
# 	detection (0.1278945493409334)
# 	different (0.26932668329177056)
# 	convolutional (0.1239757748485928)
# 	recognition (0.1392946205913787)
#
# Some Statistics words are:
# 	theoretical (0.14952333166081286)
# 	stochastic (0.13848469643753136)
# 	distribution (0.17762167586552935)
# 	statistical (0.1440040140491721)
# 	variables (0.13697942799799298)
# 	algorithm (0.3948820873055695)
# 	estimation (0.1726041144004014)
# 	dimensional (0.17711991971901656)
# 	inference (0.19468138484696437)
# 	regression (0.17661816357250376)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="1f02e8d1-7b50-47b1-82f4-f5f315a7a7f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1f02e8d1-7b50-47b1-82f4-f5f315a7a7f7")) {                    Plotly.newPlot(                        "1f02e8d1-7b50-47b1-82f4-f5f315a7a7f7",                        [{"x":["demonstrate","exploration","effective","exhibiting","integration","continuous","dimensional","challenging","including","recurrent","solutions","similarly","deterministic","identification","algorithms","strategies","observations","information","simplified","stochastic","backpropagation","partially","parameters","preserving","assortment","requirements","reinforcement","reasoning","parametric","represented","geometric","requirement","represent","framework","efficient","conceptual","operations","formalization","correlations","different","convexity","computationally","representing","projection","knowledge","influential","definition","instances","processes","recovering","statistical","nonconvex","algorithm","corruption","synthetic","contaminated","retrieval","magnitude","precision","corroborate","complexity","measurements","guaranteed","arbitrary","experiments","depression","psychological","challenge","worldwide","multimodal","independent","clustering","extraction","describes","automatically","descriptors","frustration","affecting","activities","extracted","recognition","emotional","classification","interview","validation","processing","maximizing","informativeness","unlabeled","variables","maximization","performance","respectively","benchmark","maintains","usefulness","variances","combination","labelling","retraining","perturbations","informative","technique","potential","classifier","classifiers","representative","evaluating","regression","virtually","criterion","dimensions","mainstream","differences","iterations","programming","interestingly","projections","recovered","sufficient","significant","understanding","idealized","procedure","consecutive","anomalies","applications","optimization","iteration","generated","baselines","detecting","intuition","compressed","comparisons","regardless","measurement","significantly","surveillance","typically","distribution","coordinates","orthogonal","localisation","supervised","generalises","differentiable","artifacts","detection","outperforming","manipulate","interpretable","therefore","compatibility","indicates","description","ontological","approaches","execution","interaction","important","databases","investigate","exchanged","verifying","possibility","published","conflicts","protocols","developed","interacting","inconsistent","relational","sequences","traditionally","incorporate","independently","ontologies","verification","semantically","commensurate","qualitative","tradition","determine","compatible","preference","introduce","transitivity","relaxation","uncertainty","investigates","numerical","consequences","requiring","representation","assumption","relations","particular","similarity","compression","expressing","according","incorporating","universal","parameter","automatic","corresponding","computable","semantics","designated","viability","distances","prediction","predictors","eigenvector","accuracies","simulated","reliability","covariance","independence","likelihood","questions","estimating","furthermore","malicious","correspond","predictions","proportional","available","approximation","combining","construct","conditional","estimator","discounted","maximized","identifies","polyhedral","consistent","increases","observation","memoryless","improvement","generator","containing","alternative","arabidopsis","realistic","increasing","convolutional","annotated","conditioning","generative","specifically","segmentation","artificial","phenotyping","allev ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	protected
# 	terabytes
# 	cytometry
# 	fluctuation
# 	backfitting
# 	quadrature
# 	preconditioning
# 	lucrative
# 	invariances
# 	hoeffdings
# 	tessellation
# 	hoeffding
# 	commutative
# 	integrative
# 	unnecessarily
# 	beautiful
# 	uncollapsed
# 	recasting
# 	disaggregation
# 	statistician
# Some words which never appear in Statistics papers:
# 	interview
# 	ontological
# 	commensurate
# 	memoryless
# 	certification
# 	pixelwise
# 	fuzzification
# 	societies
# 	defuzzification
# 	casualties
# 	spotlight
# 	rearrange
# 	typographic
# 	sentential
# 	paraphrases
# 	paraphrase
# 	executing
# 	obstacles
# 	elevation
# 	autonomously

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.082994203970897e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.77
